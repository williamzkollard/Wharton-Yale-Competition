# %%
import numpy as np
import pandas as pd

# %%
historical_bonds = pd.read_csv('historical_bonds.csv')
simulation_bonds = pd.read_csv('simulation_bonds.csv')

# %%
historical_bonds["credit_region"] = historical_bonds["credit_rating"] + " - " + historical_bonds["region"]

# %%
historical_bonds
# Out:
#      Unnamed: 0 credit_rating  debt_to_equity  energy_capacity  esg_rating  \
# 0             0           AAA       -0.364063         3.277333   57.459739
# 1             1            AA       -0.098335        17.823871   22.871580
# 2             2             B        0.938648        25.360441   42.125540
# 3             3             A        2.332380        38.748027   50.833794
# 4             4           AAA        1.367557        14.223886   21.952435
# ..          ...           ...             ...              ...         ...
# 995         995           CCC        0.840647        17.527648   26.744813
# 996         996           AAA        0.632371        18.241791   94.688375
# 997         997            AA        1.086183        23.294626   25.456681
# 998         998           AAA       -0.197552        77.065382   15.642536
# 999         999           BBB        1.750573        35.594508   81.144317
#
#             region   cash_flow_1   cash_flow_2   cash_flow_3  \
# ...

# %%
#plot the cash_flows against each of the variables to see if there are non linear relationships

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set figure size
plt.figure(figsize=(12, 24))

# First plot: Cash Flow distribution
plt.subplot(3, 1, 1)  # Two rows, one column, first plot
sns.boxplot(x="region", y="cash_flow_1", data=historical_bonds)
plt.xticks(rotation=45)  # Rotate x labels for better visibility
plt.title("Distribution of Cash Flow 1 by Region")
plt.xlabel("Region")
plt.ylabel("Cash Flow")
plt.grid(True)

# Second plot: Cash Flow 2 distribution
plt.subplot(3, 1, 2)  # Two rows, one column, second plot
sns.boxplot(x="region", y="cash_flow_2", data=historical_bonds)
plt.xticks(rotation=45)  # Rotate x labels for better visibility
plt.title("Distribution of Cash Flow 2 by Region")
plt.xlabel("Region")
plt.ylabel("Cash Flow 2")
plt.grid(True)

# Second plot: Cash Flow 2 distribution
plt.subplot(3, 1, 3)  # Two rows, one column, second plot
sns.boxplot(x="region", y="cash_flow_3", data=historical_bonds)
plt.xticks(rotation=45)  # Rotate x labels for better visibility
plt.title("Distribution of Cash Flow 3 by Region")
plt.xlabel("Region")
plt.ylabel("Cash Flow 3")
plt.grid(True)

# Show the plots
plt.tight_layout()  # Adjust layout for better spacing
plt.show()
# Out:
# /Users/williamkollard/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/williamkollard/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/williamkollard/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# Set figure size
plt.figure(figsize=(12, 24))

# First plot: Cash Flow distribution
plt.subplot(3, 1, 1)  # Two rows, one column, first plot
sns.boxplot(x="credit_rating", y="cash_flow_1", data=historical_bonds)
plt.xticks(rotation=45)  # Rotate x labels for better visibility
plt.title("Distribution of Cash Flow 1 by Region")
plt.xlabel("Region")
plt.ylabel("Cash Flow")
plt.grid(True)

# Second plot: Cash Flow 2 distribution
plt.subplot(3, 1, 2)  # Two rows, one column, second plot
sns.boxplot(x="credit_rating", y="cash_flow_2", data=historical_bonds)
plt.xticks(rotation=45)  # Rotate x labels for better visibility
plt.title("Distribution of Cash Flow 2 by Region")
plt.xlabel("Region")
plt.ylabel("Cash Flow 2")
plt.grid(True)

# Second plot: Cash Flow 2 distribution
plt.subplot(3, 1, 3)  # Two rows, one column, second plot
sns.boxplot(x="credit_rating", y="cash_flow_3", data=historical_bonds)
plt.xticks(rotation=45)  # Rotate x labels for better visibility
plt.title("Distribution of Cash Flow 3 by Region")
plt.xlabel("Region")
plt.ylabel("Cash Flow 3")
plt.grid(True)

# Show the plots
plt.tight_layout()  # Adjust layout for better spacing
plt.show()
# Out:
# /Users/williamkollard/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/williamkollard/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/williamkollard/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns



# Set figure size
plt.figure(figsize=(12, 24))

# First plot: Cash Flow 1 distribution by credit rating & region
plt.subplot(3, 1, 1)
sns.boxplot(x="credit_region", y="cash_flow_1", data=historical_bonds)
plt.xticks(rotation=45, ha="right")  # Rotate x labels for better visibility
plt.title("Distribution of Cash Flow 1 by Credit Rating & Region")
plt.xlabel("Credit Rating & Region")
plt.ylabel("Cash Flow 1")
plt.grid(True)

# Second plot: Cash Flow 2 distribution by credit rating & region
plt.subplot(3, 1, 2)
sns.boxplot(x="credit_region", y="cash_flow_2", data=historical_bonds)
plt.xticks(rotation=45, ha="right")
plt.title("Distribution of Cash Flow 2 by Credit Rating & Region")
plt.xlabel("Credit Rating & Region")
plt.ylabel("Cash Flow 2")
plt.grid(True)

# Third plot: Cash Flow 3 distribution by credit rating & region
plt.subplot(3, 1, 3)
sns.boxplot(x="credit_region", y="cash_flow_3", data=historical_bonds)
plt.xticks(rotation=45, ha="right")
plt.title("Distribution of Cash Flow 3 by Credit Rating & Region")
plt.xlabel("Credit Rating & Region")
plt.ylabel("Cash Flow 3")
plt.grid(True)

# Adjust layout to avoid overlap
plt.tight_layout()

# Show plots
plt.show()
# Out:
# /Users/williamkollard/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/williamkollard/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/williamkollard/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Define the correct order of credit ratings
credit_rating_order = ["CCC", "B", "BB", "BBB", "A", "AA", "AAA"]

# Convert "credit_rating" to categorical with the correct order
historical_bonds["credit_rating"] = pd.Categorical(historical_bonds["credit_rating"], categories=credit_rating_order, ordered=True)

# Sort the dataframe by region first, then by credit rating
historical_bonds = historical_bonds.sort_values(by=["region", "credit_rating"])

# Create a new column combining region and credit rating
historical_bonds["credit_region"] = historical_bonds["region"] + " - " + historical_bonds["credit_rating"].astype(str)

# Set figure size
plt.figure(figsize=(12, 24))

# First plot: Cash Flow 1 distribution by credit rating & region
plt.subplot(3, 1, 1)
sns.boxplot(x="credit_region", y="cash_flow_1", data=historical_bonds, order=historical_bonds["credit_region"].unique())
plt.xticks(rotation=45, ha="right")  # Rotate x labels for better visibility
plt.title("Distribution of Cash Flow 1 by Credit Rating & Region")
plt.xlabel("Credit Rating & Region")
plt.ylabel("Cash Flow 1")
plt.grid(True)

# Second plot: Cash Flow 2 distribution by credit rating & region
plt.subplot(3, 1, 2)
sns.boxplot(x="credit_region", y="cash_flow_2", data=historical_bonds, order=historical_bonds["credit_region"].unique())
plt.xticks(rotation=45, ha="right")
plt.title("Distribution of Cash Flow 2 by Credit Rating & Region")
plt.xlabel("Credit Rating & Region")
plt.ylabel("Cash Flow 2")
plt.grid(True)

# Third plot: Cash Flow 3 distribution by credit rating & region
plt.subplot(3, 1, 3)
sns.boxplot(x="credit_region", y="cash_flow_3", data=historical_bonds, order=historical_bonds["credit_region"].unique())
plt.xticks(rotation=45, ha="right")
plt.title("Distribution of Cash Flow 3 by Credit Rating & Region")
plt.xlabel("Credit Rating & Region")
plt.ylabel("Cash Flow 3")
plt.grid(True)

# Adjust layout to avoid overlap
plt.tight_layout()

# Show plots
plt.show()
# Out:
# /Users/williamkollard/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/williamkollard/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/williamkollard/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# the 3rd cash flows for CCC and B rated are zero for each bond for each country.
# Therefore our predictions for these cash flows needs to be zero
# There is significant distributional difference in the cash flows for different countries of the same rating.

# %% [markdown]
# We now want to produce 28 dataframes for each combination of region and credit rating.
# We then want to check for linearity/non-linearity between the debt_to_equity,
# energy_capacity and esg_rating with each cash_flow
# there are approx 40 bonds for each credit region

# %%
historical_bonds
# Out:
#      Unnamed: 0 credit_rating  debt_to_equity  energy_capacity  esg_rating  \
# 59           59           CCC        1.976712        50.028753   83.496172
# 228         228           CCC        0.955672         3.200840   68.280911
# 434         434           CCC        1.041754        32.806417   71.253088
# 491         491           CCC        1.385078        57.634901   95.806608
# 564         564           CCC        1.390020        33.440834   57.618524
# ..          ...           ...             ...              ...         ...
# 705         705           AAA        1.394395        19.976792   36.310213
# 742         742           AAA        1.622035        12.941850   47.978834
# 846         846           AAA        1.168501        11.178660   27.697626
# 894         894           AAA        1.154767        20.535659   95.217069
# 919         919           AAA        1.942847        40.308043   48.983828
#
#             region   cash_flow_1   cash_flow_2   cash_flow_3  \
# ...

# %%
asia_AAA = historical_bonds[historical_bonds["credit_region"] == "Asia - AAA"]
asia_AA = historical_bonds[historical_bonds["credit_region"] == "Asia - AA"]
asia_A = historical_bonds[historical_bonds["credit_region"] == "Asia - A"]

asia_BBB = historical_bonds[historical_bonds["credit_region"] == "Asia - BBB"]
asia_BB = historical_bonds[historical_bonds["credit_region"] == "Asia - BB"]
asia_B = historical_bonds[historical_bonds["credit_region"] == "Asia - B"]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Selecting relevant columns
sns.pairplot(asia_BBB , 
             x_vars=["debt_to_equity", "energy_capacity", "esg_rating"], 
             y_vars=["cash_flow_2"], 
             kind="scatter", 
             height=4, 
             aspect=1)

plt.suptitle("Scatter Plots of Independent Variables vs. Dependent Variable", y=1.02)
plt.show()
# Out:
# /Users/williamkollard/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/williamkollard/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/williamkollard/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
